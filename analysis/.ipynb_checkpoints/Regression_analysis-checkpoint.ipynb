# %%
import numpy as np
import pandas as pd
import os
import re
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import statsmodels.api as sm

# %%
path_ref = '..\\data\\refinitiv'

# %%
df_sample = pd.read_excel(os.path.join(path_ref,'sample.xlsx'))
df_sentiment = pd.read_csv('sentiment_scores.csv') #drop h&m and dhl
df_similarity = pd.read_csv('similarity_overall.csv')
df_verification = pd.read_csv('verification_scores.csv')

# %%
df_sample[df_sample['company'] == 'rio-tinto']
# Out:
#       company  resource use  emissions  environmental innovation  strategy
# 49  rio-tinto         79.17      83.26                     50.35     88.54

# %%
df_similarity[df_similarity['company'] == 'rio-tinto']
# Out:
#       company  dissimilarity_total  dissimilarity_total_lim  \
# 44  rio-tinto             0.555139                 0.627738
#
#     dissimilarity_average_cluster  dissimilarity_waverage_cluster  \
# 44                       0.826643                        0.716184
#
#     dissimilarity_wsum_cluster  dissimilarity_average_cluster_lim  \
# 44                    0.615135                            0.78986
#
#     dissimilarity_waverage_cluster_lim  dissimilarity_wsum_cluster_lim
# 44                            0.673234                        0.534635

# %%
df_sample
# Out:
#        company  resource use  emissions  environmental innovation  strategy
# 0          abb         62.39      99.39                     36.68     62.18
# 1       adidas         82.77      90.63                     80.68     76.89
# 2       airbus         99.43      97.09                     95.92     83.49
# 3        apple         98.51      97.50                     43.51     87.06
# 4        bayer         70.38      87.91                     82.94     95.75
# ..         ...           ...        ...                       ...       ...
# 59      veolia         74.49      79.00                     84.15     69.16
# 60  volkswagen         97.25      96.49                     92.69     96.07
# 61       volvo         96.45      88.41                     95.18     87.55
# 62     walmart         77.73      88.08                     76.81     87.01
# 63     inditex         97.61      99.33                     86.79     45.51
#
# [64 rows x 5 columns]

# %%
df_sentiment['final_score'] = MinMaxScaler().fit_transform(np.array(df_sentiment['final_score']).reshape(-1,1))

# %% [markdown]
# ### Preparing the Refinitiv data

# %%
df_sample['average_practice'] = df_sample[['resource use', 'emissions', 'environmental innovation']].replace(0, np.nan).mean(axis = 1)

# %%
df_sample['green_practice'] = StandardScaler().fit_transform(np.array(df_sample['average_practice']).reshape(-1,1))
df_sample['green_communication'] = StandardScaler().fit_transform(np.array(df_sample['strategy']).reshape(-1,1))
df_sample['discrepancy_index'] = df_sample['green_communication']-df_sample['green_practice']

# %%
df_sample['discrepancy_index'] = MinMaxScaler().fit_transform(np.array(df_sample['discrepancy_index']).reshape(-1,1))

# %%
df_sample
# Out:
#        company  resource use  emissions  environmental innovation  strategy  \
# 0          abb         62.39      99.39                     36.68     62.18
# 1       adidas         82.77      90.63                     80.68     76.89
# 2       airbus         99.43      97.09                     95.92     83.49
# 3        apple         98.51      97.50                     43.51     87.06
# 4        bayer         70.38      87.91                     82.94     95.75
# ..         ...           ...        ...                       ...       ...
# 59      veolia         74.49      79.00                     84.15     69.16
# 60  volkswagen         97.25      96.49                     92.69     96.07
# 61       volvo         96.45      88.41                     95.18     87.55
# 62     walmart         77.73      88.08                     76.81     87.01
# 63     inditex         97.61      99.33                     86.79     45.51
#
#     average_practice  discrepancy_index  green_practice  green_communication
# 0          66.153333           0.481721       -1.251297            -1.692492
# 1          84.693333           0.414026        0.283825            -0.653553
# 2          97.480000           0.333176        1.342568            -0.187407
# 3          79.840000           0.566850       -0.118034             0.064735
# 4          80.410000           0.644148       -0.070838             0.678493
# ..               ...                ...             ...                  ...
# 59         79.213333           0.401446       -0.169922            -1.199508
# 60         95.476667           0.477028        1.176690             0.701094
# 61         93.346667           0.418991        1.000325             0.099343
# 62         80.873333           0.554695       -0.032473             0.061204
# 63         94.576667           0.000000        1.102170            -2.869862
#
# [64 rows x 9 columns]

# %%
df_linreg = df_sample[['company','discrepancy_index']]
df_linreg
# Out:
#        company  discrepancy_index
# 0          abb           0.481721
# 1       adidas           0.414026
# 2       airbus           0.333176
# 3        apple           0.566850
# 4        bayer           0.644148
# ..         ...                ...
# 59      veolia           0.401446
# 60  volkswagen           0.477028
# 61       volvo           0.418991
# 62     walmart           0.554695
# 63     inditex           0.000000
#
# [64 rows x 2 columns]

# %%
df_linreg = pd.merge(df_linreg, df_similarity, how = 'left')
df_linreg = pd.merge(df_linreg, df_sentiment)
df_linreg = pd.merge(df_linreg, df_verification)
df_linreg
# Out:
#        company  discrepancy_index  dissimilarity_total  \
# 0          abb           0.481721             0.394642
# 1       adidas           0.414026             0.669004
# 2       airbus           0.333176             0.577540
# 3        apple           0.566850             0.446004
# 4        bayer           0.644148             0.693892
# ..         ...                ...                  ...
# 58      veolia           0.401446             0.371148
# 59  volkswagen           0.477028             0.671546
# 60       volvo           0.418991             0.444000
# 61     walmart           0.554695             0.344035
# 62     inditex           0.000000             0.753664
#
#     dissimilarity_total_lim  dissimilarity_average_cluster  \
# 0                  0.395509                       0.458221
# 1                  0.645366                       0.745420
# 2                  0.763859                       0.904083
# 3                  0.514624                       0.430209
# 4                  0.765657                       0.851451
# ..                      ...                            ...
# 58                 0.520925                       0.460262
# 59                 0.760529                       0.742698
# 60                 0.506159                       0.525119
# 61                 0.375118                       0.356359
# 62                 0.833904                       0.871682
#
#     dissimilarity_waverage_cluster  dissimilarity_wsum_cluster  \
# 0                         0.619573                    0.462104
# 1                         0.371327                    0.351877
# 2                         0.918818                    0.527802
# 3                         0.949415                    0.585078
# 4                         0.916687                    0.728271
# ..                             ...                         ...
# 58                        0.747798                    0.436433
# 59                        0.784993                    0.724128
# 60                        0.634637                    0.485966
# 61                        0.482016                    0.244216
# 62                        1.000000                    0.872235
#
#     dissimilarity_average_cluster_lim  dissimilarity_waverage_cluster_lim  \
# 0                            0.418272                            0.621324
# 1                            0.730806                            0.330754
# 2                            0.740525                            0.758115
# 3                            0.439572                            0.818964
# 4                            0.727430                            0.862092
# ..                                ...                                 ...
# 58                           0.321163                            0.717563
# 59                           0.715468                            0.724936
# 60                           0.468848                            0.611082
# 61                           0.282690                            0.473241
# 62                           0.815295                            0.933970
#
#     dissimilarity_wsum_cluster_lim  ...  sentiment_overall_lim  \
# 0                         0.451725  ...               0.002288
# 1                         0.320529  ...               0.214501
# 2                         0.422630  ...              -0.048930
# 3                         0.531965  ...               0.134180
# 4                         0.609459  ...              -0.174011
# ..                             ...  ...                    ...
# 58                        0.349765  ...               0.010622
# 59                        0.617212  ...               0.041562
# 60                        0.435366  ...              -0.002628
# 61                        0.215208  ...               0.064169
# 62                        0.738612  ...              -0.038931
#
#     clim_sentiment_overall_lim  clim_sentiment_cluster_average_lim  \
# 0                    -0.141260                           -0.022790
# 1                    -0.304777                           -0.207970
# 2                    -0.246560                            0.020253
# 3                    -0.002250                            0.121607
# 4                    -0.410301                           -0.346642
# ..                         ...                                 ...
# 58                   -0.005208                            0.056463
# 59                   -0.094988                           -0.110589
# 60                   -0.066098                           -0.054440
# 61                   -0.033170                           -0.061344
# 62                   -0.162326                           -0.185379
#
#     clim_sentiment_cluster_waverage_lim  clim_sentiment_cluster_wsum_lim  \
# 0                             -0.001798                        -0.014381
# 1                             -0.030220                        -0.211537
# 2                             -0.014188                        -0.127690
# 3                              0.003739                         0.033651
# 4                             -0.035077                        -0.315693
# ..                                  ...                              ...
# 58                             0.004627                         0.041646
# 59                            -0.007784                        -0.062269
# 60                            -0.000012                        -0.000097
# 61                             0.003247                         0.025979
# 62                            -0.011518                        -0.103663
#
#     sentiment_cluster_average_lim  verification_score  verification_score_lim  \
# 0                        0.024637            0.818533                0.901786
# 1                        0.104891            0.673692                0.793750
# 2                        0.004320            0.461097                0.290323
# 3                        0.217470            0.000000                0.039101
# 4                       -0.156105            0.688004                0.636029
# ..                            ...                 ...                     ...
# 58                       0.085833            1.000000                1.000000
# 59                       0.005641            0.778625                0.744845
# 60                       0.102913            0.166385                0.000000
# 61                      -0.049979            1.000000                1.000000
# 62                       0.020316            1.000000                1.000000
#
#     verification_cluster  verification_cluster_lim
# 0               0.944552                  0.987343
# 1               0.922131                  0.964139
# 2               0.919706                  0.929742
# 3               0.456722                  0.520234
# 4               0.914560                  0.914560
# ..                   ...                       ...
# 58              1.000000                  1.000000
# 59              0.957234                  0.962580
# 60              0.848840                  0.854508
# 61              1.000000                  1.000000
# 62              1.000000                  1.000000
#
# [63 rows x 30 columns]

# %%
df_correlation_scores = pd.DataFrame(columns = ['discrepancy_measure', 'correlation', 'p-value'])

# %%
from scipy.stats import pearsonr, ttest_1samp

# %%
for column in df_linreg.columns[2:]:
    df_linreg[column] = MinMaxScaler().fit_transform(np.array(df_linreg[column]).reshape(-1,1))
    
df_linreg['clim_sentiment_overall']
# Out:
# 0     0.487365
# 1     0.292901
# 2     0.368725
# 3     0.804512
# 4     0.192427
#         ...
# 58    0.636440
# 59    0.599609
# 60    0.584237
# 61    0.651766
# 62    0.548187
# Name: clim_sentiment_overall, Length: 63, dtype: float64

# %%
x = df_linreg['discrepancy_index']
for column in df_linreg.columns[2:]:
    y = df_linreg[column]
    correlation, p_value = pearsonr(x,y)
    temp_df = pd.DataFrame(
        {
            'discrepancy_measure':[column], 
            'correlation':[correlation],
            'p-value':[p_value]
        }
    )
    df_correlation_scores = pd.concat([df_correlation_scores, temp_df], ignore_index = True)

# %%
df_correlation_scores
# Out:
#                     discrepancy_measure  correlation   p-value
# 0                   dissimilarity_total    -0.072638  0.571566
# 1               dissimilarity_total_lim    -0.170547  0.181425
# 2         dissimilarity_average_cluster    -0.137835  0.281359
# 3        dissimilarity_waverage_cluster    -0.194222  0.127187
# 4            dissimilarity_wsum_cluster    -0.119293  0.351735
# 5     dissimilarity_average_cluster_lim    -0.086059  0.502451
# 6    dissimilarity_waverage_cluster_lim    -0.069772  0.586876
# 7        dissimilarity_wsum_cluster_lim    -0.037696  0.769280
# 8                     sentiment_overall     0.095820  0.455040
# 9             sentiment_cluster_average     0.004660  0.971088
# 10           sentiment_cluster_waverage     0.061403  0.632604
# 11               sentiment_cluster_wsum     0.070297  0.584055
# 12               clim_sentiment_overall     0.219188  0.084353
# 13    climate_sentiment_cluster_average     0.184183  0.148449
# 14   climate_sentiment_cluster_waverage     0.112861  0.378489
# 15       climate_sentiment_cluster_wsum     0.133311  0.297601
# 16       sentiment_cluster_waverage_lim     0.071865  0.575676
# 17           sentiment_cluster_wsum_lim     0.074130  0.563671
# 18                sentiment_overall_lim     0.087589  0.494855
# 19           clim_sentiment_overall_lim     0.142802  0.264211
# 20   clim_sentiment_cluster_average_lim     0.060112  0.639789
# 21  clim_sentiment_cluster_waverage_lim     0.090867  0.478784
# 22      clim_sentiment_cluster_wsum_lim     0.098371  0.443069
# 23        sentiment_cluster_average_lim     0.003374  0.979060
# 24                   verification_score    -0.004761  0.970458
# 25               verification_score_lim     0.025371  0.843536
# 26                 verification_cluster    -0.036839  0.774385
# 27             verification_cluster_lim     0.035129  0.784600

# %%
filter_results = []
for measure in df_correlation_scores['discrepancy_measure']:
    if ('_lim' in measure)|('waverage' in measure)|('wsum' in measure):
        filter_results.append(False)
    else:
        filter_results.append(True)
df_results = df_correlation_scores[filter_results]
df_results.reset_index(inplace = True, drop = True)
df_results
# Out:
#                  discrepancy_measure  correlation   p-value
# 0                dissimilarity_total    -0.072638  0.571566
# 1      dissimilarity_average_cluster    -0.137835  0.281359
# 2                  sentiment_overall     0.095820  0.455040
# 3          sentiment_cluster_average     0.004660  0.971088
# 4             clim_sentiment_overall     0.219188  0.084353
# 5  climate_sentiment_cluster_average     0.184183  0.148449
# 6                 verification_score    -0.004761  0.970458
# 7               verification_cluster    -0.036839  0.774385

# %%
df_results = df_results.iloc[[0,1,4,5,6,7]]
df_results.reset_index(inplace = True, drop = True)

# %%
df_results['discrepancy_measure'] = ['Dissimilarity_firm', 'Dissimilarity_firm-topic', 'Sentiment_firm', 'Sentiment_firm-topic', 'Verification_firm', 'Verification_firm-topic']
df_results
# Out:
# C:\Users\dathn\AppData\Local\Temp\ipykernel_12268\1483800314.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_results['discrepancy_measure'] = ['Dissimilarity_firm', 'Dissimilarity_firm-topic', 'Sentiment_firm', 'Sentiment_firm-topic', 'Verification_firm', 'Verification_firm-topic']
#         discrepancy_measure  correlation   p-value
# 0        Dissimilarity_firm    -0.072638  0.571566
# 1  Dissimilarity_firm-topic    -0.137835  0.281359
# 2            Sentiment_firm     0.219188  0.084353
# 3      Sentiment_firm-topic     0.184183  0.148449
# 4         Verification_firm    -0.004761  0.970458
# 5   Verification_firm-topic    -0.036839  0.774385

# %%
print(df_results.to_latex(index = False, caption = 'Correlation Analysis Results for the Developed Greenwashing Scores on Document and Cluster Level', label = 'tab:correlationresults', header = True, position = 'h'))
# Out:
# \begin{table}[h]
# \centering
# \caption{Correlation Analysis Results for the Developed Greenwashing Scores on Document and Cluster Level}
# \label{tab:correlationresults}
# \begin{tabular}{lrr}
# \toprule
#      discrepancy\_measure &  correlation &  p-value \\
# \midrule
#       Dissimilarity\_firm &    -0.072638 & 0.571566 \\
# Dissimilarity\_firm-topic &    -0.137835 & 0.281359 \\
#           Sentiment\_firm &     0.219188 & 0.084353 \\
#     Sentiment\_firm-topic &     0.184183 & 0.148449 \\
#        Verification\_firm &    -0.004761 & 0.970458 \\
#  Verification\_firm-topic &    -0.036839 & 0.774385 \\
# \bottomrule
# \end{tabular}
# \end{table}
# C:\Users\dathn\AppData\Local\Temp\ipykernel_12268\2245298321.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df_results.to_latex(index = False, caption = 'Correlation Analysis Results for the Developed Greenwashing Scores on Document and Cluster Level', label = 'tab:correlationresults', header = True, position = 'h'))

# %%
df_sentiment['clim_sentiment_overall'].plot.box()
# Out:
# <Axes: >

# %%
df_sentiment[df_sentiment['clim_sentiment_overall']>0]
# Out:
#        company  sentiment_overall  sentiment_cluster_average  \
# 0       google           0.118567                   0.106422
# 18     chevron           0.182620                   0.119269
# 19       exxon           0.222693                   0.158016
# 24      danone           0.174119                   0.089561
# 29   starbucks           0.290489                   0.369199
# 53  ford-motor           0.052083                   0.035752
# 56       tesco           0.158527                   0.195224
# 57   blackrock           0.065933                   0.042576
# 60      dupont           0.200516                   0.114522
# 62       apple           0.148275                   0.210894
#
#     sentiment_cluster_waverage  sentiment_cluster_wsum  \
# 0                     0.008713                0.087127
# 18                    0.016840                0.185244
# 19                    0.022521                0.247728
# 24                    0.016113                0.161129
# 29                    0.023305                0.256350
# 53                    0.001561                0.018735
# 56                    0.012379                0.148542
# 57                    0.008853                0.079679
# 60                    0.017925                0.197178
# 62                    0.011881                0.154453
#
#     clim_sentiment_overall  climate_sentiment_cluster_average  \
# 0                 0.012438                           0.087597
# 18                0.107853                           0.132868
# 19                0.068282                           0.016314
# 24                0.126692                           0.118797
# 29                0.086163                           0.217373
# 53                0.055372                           0.044512
# 56                0.038179                           0.057462
# 57                0.001474                          -0.076190
# 60                0.202174                           0.346026
# 62                0.052469                           0.130685
#
#     climate_sentiment_cluster_waverage  climate_sentiment_cluster_wsum  \
# 0                            -0.000607                       -0.006065
# 18                            0.014364                        0.158004
# 19                            0.012127                        0.133393
# 24                            0.013885                        0.138852
# 29                            0.009462                        0.104084
# 53                            0.004658                        0.055890
# 56                            0.007522                        0.090267
# 57                           -0.001781                       -0.016032
# 60                            0.016308                        0.179388
# 62                            0.004840                        0.062921
#
#     sentiment_cluster_waverage_lim  sentiment_cluster_wsum_lim  \
# 0                         0.011810                    0.082669
# 18                        0.020183                    0.181651
# 19                        0.033842                    0.270737
# 24                        0.021780                    0.152463
# 29                        0.034428                    0.275425
# 53                        0.007503                    0.067526
# 56                        0.016649                    0.149844
# 57                        0.004302                    0.025810
# 60                        0.032419                    0.259356
# 62                        0.015917                    0.143254
#
#     sentiment_overall_lim  clim_sentiment_overall_lim  \
# 0                0.110629                   -0.040402
# 18               0.155454                    0.068745
# 19               0.232968                    0.019765
# 24               0.166500                    0.119718
# 29               0.318431                    0.117149
# 53               0.092469                    0.121414
# 56               0.150869                    0.041109
# 57              -0.066373                   -0.148546
# 60               0.258334                    0.223924
# 62               0.134180                   -0.002250
#
#     clim_sentiment_cluster_average_lim  clim_sentiment_cluster_waverage_lim  \
# 0                            -0.013998                            -0.006708
# 18                            0.127410                             0.018044
# 19                           -0.020291                             0.014870
# 24                            0.090253                             0.018149
# 29                            0.173094                             0.016073
# 53                            0.094197                             0.012688
# 56                            0.005669                             0.010765
# 57                           -0.065196                            -0.010658
# 60                            0.261919                             0.025791
# 62                            0.121607                             0.003739
#
#     clim_sentiment_cluster_wsum_lim  sentiment_cluster_average_lim
# 0                         -0.046957                       0.106857
# 18                         0.162398                       0.098749
# 19                         0.118960                       0.154520
# 24                         0.127044                       0.118615
# 29                         0.128588                       0.310002
# 53                         0.114196                       0.061385
# 56                         0.096886                       0.182461
# 57                        -0.063950                       0.047247
# 60                         0.206330                       0.115441
# 62                         0.033651                       0.217470

# %%
df_linreg['clim_sentiment_overall'].mean()
# Out:
# 0.5537758492847364

# %%
df_linreg['discrepancy_index'] = MinMaxScaler().fit_transform(np.array(df_linreg['discrepancy_index']).reshape(-1,1))

# %%
df_linreg.set_index('company', inplace = True)

# %%
df_linreg
# Out:
#                ESG governance  Emission Reduction  Waste Management  \
# company
# rio-tinto           -0.103401           -0.118888          0.315222
# walmart              0.007098            0.063356          0.073705
# colgate              0.114434            0.066575         -0.044937
# general-mills       -0.062815            0.007971         -0.185231
# hp                  -0.080099           -0.158046         -0.027431
# ...                       ...                 ...               ...
# adidas              -0.003448            0.293583          0.098622
# hyundai              0.042043           -0.102316         -0.034380
# intel                0.125090            0.207181         -0.075009
# bmw                 -0.234862            0.113722          0.058844
# starbucks            0.065670            0.384684          0.259640
#
#                Renewable Energy  Plastics Recyling  Electrical Vehicles  \
# company
# rio-tinto             -0.076896           0.623388            -0.104418
# walmart               -0.227604           0.030754            -0.283509
# colgate               -0.419891           0.065245                  NaN
# general-mills          0.031976          -0.213897                  NaN
# hp                     0.018113          -0.037755             0.125385
# ...                         ...                ...                  ...
# adidas                 0.148214          -0.018610            -0.129327
# hyundai                0.024789           0.216669             0.135543
# intel                  0.134263           0.077224             0.261944
# bmw                    0.042602                NaN             0.206232
# starbucks              0.175194           0.245007             0.070400
#
#                Climate Change  Nature Conservation  \
# company
# rio-tinto            0.069384             0.360745
# walmart              0.094747             0.065251
# colgate             -0.005104            -0.015416
# general-mills        0.264606            -0.249514
# hp                   0.041401            -0.157452
# ...                       ...                  ...
# adidas               0.029701             0.256966
# hyundai             -0.122541            -0.169336
# intel                0.305286             0.153274
# bmw                  0.006581            -0.170647
# starbucks            0.809779             0.511253
#
#                Sustainable Transportation  Sustainable Agriculure  ...  \
# company                                                            ...
# rio-tinto                       -0.046325                     NaN  ...
# walmart                               NaN                0.063302  ...
# colgate                               NaN               -0.323991  ...
# general-mills                   -0.884435               -0.139983  ...
# hp                               0.215793               -0.205014  ...
# ...                                   ...                     ...  ...
# adidas                                NaN                     NaN  ...
# hyundai                          0.205020               -0.912826  ...
# intel                           -0.133883                     NaN  ...
# bmw                              0.036271                     NaN  ...
# starbucks                             NaN                0.500723  ...
#
#                       5         6         7         8        10        11  \
# company
# rio-tinto      0.334281  0.483329  0.232824  0.408051       NaN  0.214380
# walmart        0.182003  0.505852  0.475088       NaN  0.468949  0.243316
# colgate             NaN  0.191898  0.245663       NaN  0.232664       NaN
# general-mills       NaN  0.413579  0.391257  0.144090  0.506694  0.159895
# hp             0.467884  0.508401  0.404933  0.341146  0.166339  0.363206
# ...                 ...       ...       ...       ...       ...       ...
# adidas         0.094742  0.376804  0.321279       NaN       NaN  0.212580
# hyundai        0.530615  0.330169  0.299412  0.569242  0.100385  0.275194
# intel          0.229873  0.454132  0.471610  0.374688       NaN  0.494387
# bmw            0.521349  0.579657  0.249247  0.527049       NaN       NaN
# starbucks      0.479437  0.235058  0.442646       NaN  0.531541  0.150398
#
#                      20  25   average  dissimilarity
# company
# rio-tinto      0.179743 NaN  0.173357       0.826643
# walmart        0.240421 NaN  0.643641       0.356359
# colgate        0.332284 NaN  0.205470       0.794530
# general-mills  0.554802 NaN  0.317077       0.682923
# hp             0.189046 NaN  0.543057       0.456943
# ...                 ...  ..       ...            ...
# adidas         0.260169 NaN  0.254580       0.745420
# hyundai             NaN NaN  0.492684       0.507316
# intel          0.330656 NaN  0.624501       0.375499
# bmw                 NaN NaN  0.811204       0.188796
# starbucks      0.261580 NaN  0.652402       0.347598
#
# [63 rows x 37 columns]

# %%
df_sentiment_total = pd.read_csv('sentiment_overall.csv')
df_sentiment_total[df_sentiment_total['company'] == 'rio-tinto']
# Out:
#       company     value
# 14  rio-tinto -0.073053

# %%
df_similarity_total = pd.read_csv('similarity_overall.csv')

# %%
df_linreg = pd.merge(df_linreg, df_sentiment_total, how = 'left', left_on = df_linreg.index, right_on = 'company')

# %%
df_linreg = pd.merge(df_similarity_total, df_sample,  how = 'left')

# %%
df_linreg[df_linreg['dissimilarity_total'].isnull()]
# Out:
# Empty DataFrame
# Columns: [company, sim_score, dissimilarity_total, resource use, emissions, environmental innovation, strategy, average_practice, green_practice, green_communication, discrepancy_index]
# Index: []

# %%
df_linreg[df_linreg['company'] =='rio-tinto']['discrepancy_index']
# Out:
# 0    0.681803
# Name: discrepancy_index, dtype: float64

# %%
df_linreg
# Out:
#           company  sim_score  dissimilarity_total  resource use  emissions  \
# 0         nextera   0.576124             0.423876         93.43      85.69
# 1         chevron   0.781576             0.218424         74.35      86.22
# 2    ralph-lauren   0.315532             0.684468         86.13      82.59
# 3       coca-cola   0.608070             0.391930         72.06      42.13
# 4      mitsubishi   0.029763             0.970237         97.50      67.50
# ..            ...        ...                  ...           ...        ...
# 58          shell   0.481304             0.518696         95.39      97.45
# 59          tesla   0.545558             0.454442         56.51      68.65
# 60  totalenergies   0.305087             0.694913         93.91      98.47
# 61        colgate   0.510728             0.489272         99.24      93.57
# 62         sonoco   0.296214             0.703786         84.25      54.11
#
#     environmental innovation  strategy  average_practice  green_practice  \
# 0                      63.03     87.01         80.716667       -0.045445
# 1                      79.38     93.33         79.983333       -0.106166
# 2                      80.68     92.38         83.133333        0.154656
# 3                      90.52     99.51         68.236667       -1.078796
# 4                      83.33     97.05         82.776667        0.125124
# ..                       ...       ...               ...             ...
# 58                     79.38     97.68         90.740000        0.784492
# 59                     86.92     78.64         70.693333       -0.875383
# 60                     79.38     98.13         90.586667        0.771796
# 61                     90.48     97.08         94.430000        1.090026
# 62                     41.04     72.24         59.800000       -1.777357
#
#     green_communication  discrepancy_index
# 0              0.061204           0.556465
# 1              0.507573           0.625649
# 2              0.440476           0.580910
# 3              0.944055           0.817897
# 4              0.770310           0.629939
# ..                  ...                ...
# 58             0.814805           0.546050
# 59            -0.529953           0.589042
# 60             0.846588           0.552119
# 61             0.772428           0.498584
# 62            -0.981973           0.650431
#
# [63 rows x 11 columns]

# %%
df_linreg.index
# Out:
# Index(['rio-tinto', 'walmart', 'colgate', 'general-mills', 'hp', 'shell',
#        'p&g', 'exxon', 'komatsu', 'bayer', 'inditex', 'google', 'diageo',
#        'ibm', 'mcdonald', 'tesla', 'mercedes', 'toyota', 'sonoco', 'h&m',
#        'totalenergies', 'chipotle', 'coca-cola', 'eversource', 'honda',
#        'renault', 'citi', 'dell', 'beiersdorf', 'pepsico', 'airbus', 'henkel',
#        'mitsubishi', 'ralph-lauren', 'dupont', 'tesco', 'hershey', 'nike',
#        'boeing', 'abb', 'cemex', 'blackrock', 'ford-motor', 'danone', 'enel',
#        'volvo', 'volkswagen', 'nestle', 'linde', 'edp', 'schneider-electric',
#        'apple', 'mondelez', 'microsoft', 'nextera', 'veolia', 'chevron', 'dhl',
#        'adidas', 'hyundai', 'intel', 'bmw', 'starbucks'],
#       dtype='object', name='company')

# %%
X = df_linreg['value']
y = df_linreg['discrepancy_index']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      discrepancy_index   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.5653
# Date:                Tue, 16 May 2023   Prob (F-statistic):              0.455
# Time:                        21:24:18   Log-Likelihood:                 19.086
# No. Observations:                  63   AIC:                            -34.17
# Df Residuals:                      61   BIC:                            -29.89
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5379      0.023     23.363      0.000       0.492       0.584
# value          0.1560      0.207      0.752      0.455      -0.259       0.571
# ==============================================================================
# Omnibus:                        3.375   Durbin-Watson:                   1.699
# Prob(Omnibus):                  0.185   Jarque-Bera (JB):                2.625
# Skew:                          -0.302   Prob(JB):                        0.269
# Kurtosis:                       3.798   Cond. No.                         9.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = df_linreg['dissimilarity_total']
y = df_linreg['discrepancy_index']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      discrepancy_index   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.5653
# Date:                Tue, 16 May 2023   Prob (F-statistic):              0.455
# Time:                        22:01:22   Log-Likelihood:                 19.086
# No. Observations:                  63   AIC:                            -34.17
# Df Residuals:                      61   BIC:                            -29.89
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.5832      0.062      9.395      0.000       0.459       0.707
# dissimilarity_total    -0.0770      0.102     -0.752      0.455      -0.282       0.128
# ==============================================================================
# Omnibus:                        3.375   Durbin-Watson:                   1.569
# Prob(Omnibus):                  0.185   Jarque-Bera (JB):                2.625
# Skew:                          -0.302   Prob(JB):                        0.269
# Kurtosis:                       3.798   Cond. No.                         5.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
